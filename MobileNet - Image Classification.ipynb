# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17225924/17225924 [==============================] - 7s 0us/step

# %%
def prepare_image(file):
    img_path = 'C:/Users/yuvar/Deep learning/mobile_net_samples/'
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='C:/Users/yuvar/Deep learning/mobile_net_samples/1.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('1.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# [[('n01682714', 'American_chameleon', 0.6527745),
#   ('n01693334', 'green_lizard', 0.1893009),
#   ('n01687978', 'agama', 0.13809507),
#   ('n01689811', 'alligator_lizard', 0.013602536),
#   ('n01688243', 'frilled_lizard', 0.004319298)]]

# %%
Image(filename='C:/Users/yuvar/Deep learning/mobile_net_samples/2.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('2.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 86ms/step
# [[('n07920052', 'espresso', 0.9766623),
#   ('n07930864', 'cup', 0.0100936815),
#   ('n07932039', 'eggnog', 0.008597038),
#   ('n03063599', 'coffee_mug', 0.003665174),
#   ('n04597913', 'wooden_spoon', 0.0004963695)]]

# %%
Image(filename='C:/Users/yuvar/Deep learning/mobile_net_samples/3.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('3.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 87ms/step
# [[('n07745940', 'strawberry', 0.99999344),
#   ('n07749582', 'lemon', 1.2431725e-06),
#   ('n07747607', 'orange', 8.595115e-07),
#   ('n07753275', 'pineapple', 8.273909e-07),
#   ('n07768694', 'pomegranate', 6.2610394e-07)]]

# %%
Image(filename='C:/Users/yuvar/Deep learning/mobile_net_samples/4.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('4.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 126ms/step
# [[('n03127747', 'crash_helmet', 0.870979),
#   ('n03623198', 'knee_pad', 0.046114087),
#   ('n04251144', 'snorkel', 0.010660157),
#   ('n04356056', 'sunglasses', 0.008146259),
#   ('n04355933', 'sunglass', 0.006877013)]]

# %%
Image(filename='C:/Users/yuvar/Deep learning/mobile_net_samples/5.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('5.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 89ms/step
# [[('n02504458', 'African_elephant', 0.8466491),
#   ('n01871265', 'tusker', 0.07777425),
#   ('n02504013', 'Indian_elephant', 0.07540856),
#   ('n02397096', 'warthog', 0.00011728199),
#   ('n01695060', 'Komodo_dragon', 1.616786e-05)]]

# %%
Image(filename='C:/Users/yuvar/Deep learning/mobile_net_samples/6.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('6.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 125ms/step
# [[('n04285008', 'sports_car', 0.97577536),
#   ('n04037443', 'racer', 0.02175264),
#   ('n03100240', 'convertible', 0.0006850378),
#   ('n02974003', 'car_wheel', 0.00059938105),
#   ('n03459775', 'grille', 0.0004813072)]]
